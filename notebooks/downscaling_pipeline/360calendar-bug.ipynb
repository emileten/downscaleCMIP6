# %%
# %%capture
! pip install xclim

# %%
from dodola.core import standardize_gcm
from dodola.repository import write
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/statsmodels/compat/pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
import xarray as xr
import numpy as np

# %%
from science_validation_manual import *

# %%
ds = read_gcs_zarr('gs://scratch-170cd6ec/0efe3fcb-3a7c-4130-949c-0b448880cadf/e2e-ec-earth3-pr-97j78-1006015771/timesliced.zarr')
ds.load() # peaks at 21 GB and then stabilizes at ~9 (roughly the size of the data)
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 256, bnds: 2, lon: 512, member_id: 1, time: 31411)
# Coordinates:
#   * lat        (lat) float64 -89.46 -88.77 -88.07 -87.37 ... 88.07 88.77 89.46
#     lat_bnds   (lat, bnds) float64 -90.0 -89.11 -89.11 ... 89.11 89.11 90.0
#   * lon        (lon) float64 0.0 0.7031 1.406 2.109 ... 357.2 357.9 358.6 359.3
#     lon_bnds   (lon, bnds) float64 -0.3516 0.3516 0.3516 ... 358.9 358.9 359.6
#   * member_id  (member_id) <U8 'r1i1p1f1'
#   * time       (time) datetime64[ns] 2015-01-01T12:00:00 ... 2100-12-31T12:00:00
#     time_bnds  (time, bnds) datetime64[ns] 2015-01-01 2015-01-02 ... 2101-01-01
# Dimensions without coordinates: bnds
# Data variables:
#     pr         (member_id, time, lat, lon) float32 -1.348e-25 ... 3.286e-05
# Attributes: (12/52)
#     Conventions:             CF-1.7 CMIP-6.2
#     activity_id:             ScenarioMIP
#     branch_method:           standard
#     branch_time:             0.0
# ...

# %%
#standardize_gcm(ds)

# %%
from dodola.core import xclim_remove_leapdays

# %%
ds_converted = xclim_remove_leapdays(ds)
